# %%
import svgwrite
import random
from svglib.svglib import svg2rlg
from reportlab.graphics import renderPM
import math
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f646b1c7f7da> in <module>
# ----> 1 import svgwrite
#       2 import random
#       3 from svglib.svglib import svg2rlg
#       4 from reportlab.graphics import renderPM
#       5 import math
#
# ModuleNotFoundError: No module named 'svgwrite'

# %%
name = "triangle.svg"
svg_size_width = 70
svg_size_height = 70
TRIHEIGHT = math.sqrt(3)/2.0

dwg = svgwrite.Drawing(name, (svg_size_width, svg_size_height))
pos, x_min, y_min, x_max, y_max, x_circ, y_circ, rad_circ, rec_size = shape_create()

dwg.add(dwg.rect((x_min, y_min), (rec_size,rec_size),
    stroke=svgwrite.rgb(120, 120, 120, '%'), 
    fill='rgb(0,0,0)')
)

draw_triangle((x_min+7.5,y_min-7.5), 10, 'rgb(120,120,120)', rotate = 60)
dwg.save()
drawing = svg2rlg(name)
new_name = name.strip(".svg")
new_name = new_name + ".png"
renderPM.drawToFile(drawing, new_name, fmt="PNG")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0b61526fa834> in <module>
#       5
#       6 dwg = svgwrite.Drawing(name, (svg_size_width, svg_size_height))
# ----> 7 pos, x_min, y_min, x_max, y_max, x_circ, y_circ, rad_circ, rec_size = shape_create()
#       8
#       9 dwg.add(dwg.rect((x_min, y_min), (rec_size,rec_size),
#
# NameError: name 'shape_create' is not defined

# %%
def draw_triangle(insert, size, fill, rotate=None):
    x, y = insert
    points = [insert, (x + size, y), ((x + size / 2.0), (y + size * TRIHEIGHT))]
    triangle = dwg.add(dwg.polygon(points, fill=fill, stroke=svgwrite.rgb(0, 255, 0, '%')))
    if rotate:
            triangle.rotate(rotate, center=insert)

# %%
def shape_create():
    x_min = random.randrange(10,50)
    y_min = random.randrange(10,50)
    x_circ = random.randrange(10,50)
    y_circ = random.randrange(10,50)
    x_circ1 = random.randrange(10,50)
    y_circ1 = random.randrange(10,50)
    rad_circ = 6
    rec_size = 15
    x_max = x_min + rec_size
    y_max = y_min + rec_size

    in_square = False
    on_line = False
    out_square = False
    
    if x_circ < (x_max + rad_circ) and x_circ > (x_min - rad_circ) :
        if y_circ < (y_max + rad_circ) and y_circ > (y_min - rad_circ) :
            if abs(x_min - x_circ) <= rad_circ:
                on_line = True
            elif abs(x_max - x_circ) <= rad_circ:
                on_line = True
            elif abs(y_min - y_circ) <= rad_circ:
                on_line = True
            elif abs(y_max - y_circ) <= rad_circ:
                on_line = True
            else :
                in_square = True
        else:
            out_square = True
    else:
        out_square = True
    
    
    if in_square:
        return 0, x_min, y_min, x_max, y_max, x_circ, y_circ, rad_circ, rec_size
    if on_line:
        return 1, x_min, y_min, x_max, y_max, x_circ, y_circ, rad_circ, rec_size
    if out_square:
        return 2, x_min, y_min, x_max, y_max, x_circ, y_circ, rad_circ, rec_size
    else:
        return 2, x_min, y_min, x_max, y_max, x_circ, y_circ, rad_circ, rec_size

# %%
#CODE TO GET 6 POINTS

svg_size_width = 70
svg_size_height = 70

in_square_count = 1500
out_square_count = 0
on_line_count = 0

count = 0


while (in_square_count != 0) or (on_line_count != 0) or (out_square_count != 0) :
    count += 1
    pos, x_min, y_min, x_max, y_max, x_circ, y_circ, rad_circ, rec_size = shape_create()
    if pos == 0:
        if in_square_count == 0:
            continue

        in_square_count -= 1
        name = "best6" + str(in_square_count) + ".svg"
    if pos == 1:
        if on_line_count == 0:
            continue
        on_line_count -= 1
        name = "on_line" + str(on_line_count) + ".svg"
    if pos == 2:
        if out_square_count == 0:
            continue
        #x_circ1 = random.randrange(10,50)
        #y_circ1 = random.randrange(10,50)
        #if abs(x_circ1 - x_circ)<10:
        #    continue
        #if abs(y_circ1 - y_min) < 10:
        #    continue
        out_square_count -= 1
        name = "trainglecirclerand" + str(out_square_count) + ".svg"

    dwg = svgwrite.Drawing(name, (svg_size_width, svg_size_height))

    dwg.add(dwg.rect((x_min, y_min), (rec_size,rec_size),
        stroke=svgwrite.rgb(255, 0, 0, '%'), 
        fill='red')
    )
    dwg.add(dwg.circle(center=(x_circ,y_circ),
    r=rad_circ, 
    stroke=svgwrite.rgb(0, 0, 255, '%'),
    fill='blue')
    )
    traingle_x_jitter = random.randrange(6,10)
    traingle_y_jitter = random.randrange(8,12)
    #x_ran =random.randrange(10,50)
    #y_ran =random.randrange(10,50)
    draw_triangle((x_min+traingle_x_jitter,y_min-traingle_y_jitter), 10, 'rgb(0,255,0)', rotate = 60)
    #draw_triangle((x_circ1,y_circ1), 10, 'rgb(0,255,0)', rotate = 60)
    dwg.save()
    drawing = svg2rlg(name)
    new_name = name.strip(".svg")
    new_name = new_name + ".png"
    renderPM.drawToFile(drawing, new_name, fmt="PNG")

print(count)
# Out:
# 938059

# %%
#CODE TO GET 4 POINTS insquare

svg_size_width = 70
svg_size_height = 70

in_square_count = 1000
out_square_count = 0
on_line_count = 0

count = 0


while (in_square_count != 0) or (on_line_count != 0) or (out_square_count != 0) :
    count += 1
    pos, x_min, y_min, x_max, y_max, x_circ, y_circ, rad_circ, rec_size = shape_create()
    if pos == 0:
        if in_square_count == 0:
            continue

        in_square_count -= 1
        name = "insquare4" + str(in_square_count) + ".svg"
    if pos == 1:
        if on_line_count == 0:
            continue
        on_line_count -= 1
        name = "on_line" + str(on_line_count) + ".svg"
    if pos == 2:
        if out_square_count == 0:
            continue
        #x_circ1 = random.randrange(10,50)
        #y_circ1 = random.randrange(10,50)
        #if abs(x_circ1 - x_circ)<10:
        #    continue
        #if abs(y_circ1 - y_min) < 10:
        #    continue
        out_square_count -= 1
        name = "trainglecirclerand" + str(out_square_count) + ".svg"

    dwg = svgwrite.Drawing(name, (svg_size_width, svg_size_height))

    dwg.add(dwg.rect((x_min, y_min), (rec_size,rec_size),
        stroke=svgwrite.rgb(0, 0, 0, '%'), 
        fill='white')
    )
    dwg.add(dwg.circle(center=(x_circ,y_circ),
    r=rad_circ, 
    stroke=svgwrite.rgb(0, 0, 0, '%'),
    fill='white')
    )
    #traingle_x_jitter = random.randrange(6,10)
    #traingle_y_jitter = random.randrange(8,12)
    #x_ran =random.randrange(10,50)
    #y_ran =random.randrange(10,50)
    #draw_triangle((x_min+traingle_x_jitter,y_min-traingle_y_jitter), 10, 'rgb(0,255,0)', rotate = 60)
    #draw_triangle((x_circ1,y_circ1), 10, 'rgb(0,255,0)', rotate = 60)
    dwg.save()
    drawing = svg2rlg(name)
    new_name = name.strip(".svg")
    new_name = new_name + ".png"
    renderPM.drawToFile(drawing, new_name, fmt="PNG")

print(count)
# Out:
# 64050

# %%
#CODE TO GET 4 POINTS square triangle

svg_size_width = 70
svg_size_height = 70

in_square_count = 1000
out_square_count = 0
on_line_count = 0

count = 0


while (in_square_count != 0) or (on_line_count != 0) or (out_square_count != 0) :
    count += 1
    pos, x_min, y_min, x_max, y_max, x_circ, y_circ, rad_circ, rec_size = shape_create()
    if pos == 0:
        if in_square_count == 0:
            continue

        in_square_count -= 1
        name = "triagnlesquare" + str(in_square_count) + ".svg"
    if pos == 1:
        if on_line_count == 0:
            continue
        on_line_count -= 1
        name = "on_line" + str(on_line_count) + ".svg"
    if pos == 2:
        if out_square_count == 0:
            continue
        #x_circ1 = random.randrange(10,50)
        #y_circ1 = random.randrange(10,50)
        #if abs(x_circ1 - x_circ)<10:
        #    continue
        #if abs(y_circ1 - y_min) < 10:
        #    continue
        out_square_count -= 1
        name = "trainglecirclerand" + str(out_square_count) + ".svg"

    dwg = svgwrite.Drawing(name, (svg_size_width, svg_size_height))

    dwg.add(dwg.rect((x_min, y_min), (rec_size,rec_size),
        stroke=svgwrite.rgb(0, 0, 0, '%'), 
        fill='white')
    )
    #dwg.add(dwg.circle(center=(x_circ,y_circ),
    #r=rad_circ, 
    #stroke=svgwrite.rgb(0, 0, 255, '%'),
    #fill='blue')
    #)
    traingle_x_jitter = random.randrange(6,10)
    traingle_y_jitter = random.randrange(8,12)
    #x_ran =random.randrange(10,50)
    #y_ran =random.randrange(10,50)
    draw_triangle((x_min+traingle_x_jitter,y_min-traingle_y_jitter), 10, 'white', rotate = 60)
    #draw_triangle((x_circ1,y_circ1), 10, 'rgb(0,255,0)', rotate = 60)
    dwg.save()
    drawing = svg2rlg(name)
    new_name = name.strip(".svg")
    new_name = new_name + ".png"
    renderPM.drawToFile(drawing, new_name, fmt="PNG")

print(count)
# Out:
# 66219

# %%
#CODE TO GET 4 POINTS circle triangle

svg_size_width = 70
svg_size_height = 70

in_square_count = 1000
out_square_count = 0
on_line_count = 0

count = 0


while (in_square_count != 0) or (on_line_count != 0) or (out_square_count != 0) :
    count += 1
    pos, x_min, y_min, x_max, y_max, x_circ, y_circ, rad_circ, rec_size = shape_create()
    if pos == 0:
        if in_square_count == 0:
            continue
        in_square_count -= 1
        name = "trianglecircle" + str(in_square_count) + ".svg"
    if pos == 1:
        if on_line_count == 0:
            continue
        on_line_count -= 1
        name = "on_line" + str(on_line_count) + ".svg"
    if pos == 2:
        if out_square_count == 0:
            continue
        #x_circ1 = random.randrange(10,50)
        #y_circ1 = random.randrange(10,50)
        #if abs(x_circ1 - x_circ)<10:
        #    continue
        #if abs(y_circ1 - y_min) < 10:
        #    continue
        out_square_count -= 1
        name = "trainglecirclerand" + str(out_square_count) + ".svg"

    dwg = svgwrite.Drawing(name, (svg_size_width, svg_size_height))

    #dwg.add(dwg.rect((x_min, y_min), (rec_size,rec_size),
    #    stroke=svgwrite.rgb(255, 0, 0, '%'), 
    #    fill='red')
    #)
    dwg.add(dwg.circle(center=(x_circ,y_circ),
    r=rad_circ, 
    stroke=svgwrite.rgb(0, 0, 0, '%'),
    fill='white')
    )
    traingle_x_jitter = random.randrange(6,10)
    traingle_y_jitter = random.randrange(8,12)
    #x_ran =random.randrange(10,50)
    #y_ran =random.randrange(10,50)
    draw_triangle((x_min+traingle_x_jitter,y_min-traingle_y_jitter), 10, 'white', rotate = 60)
    #draw_triangle((x_circ1,y_circ1), 10, 'rgb(0,255,0)', rotate = 60)
    dwg.save()
    drawing = svg2rlg(name)
    new_name = name.strip(".svg")
    new_name = new_name + ".png"
    renderPM.drawToFile(drawing, new_name, fmt="PNG")

print(count)
# Out:
# 66864

# %%
#CODE TO GET 1 point triangle

svg_size_width = 70
svg_size_height = 70

in_square_count = 1000
out_square_count = 0
on_line_count = 0

count = 0


while (in_square_count != 0) or (on_line_count != 0) or (out_square_count != 0) :
    count += 1
    pos, x_min, y_min, x_max, y_max, x_circ, y_circ, rad_circ, rec_size = shape_create()
    if pos == 0:
        if in_square_count == 0:
            continue
        in_square_count -= 1
        name = "singletriangle" + str(in_square_count) + ".svg"
    if pos == 1:
        if on_line_count == 0:
            continue
        on_line_count -= 1
        name = "on_line" + str(on_line_count) + ".svg"
    if pos == 2:
        if out_square_count == 0:
            continue
        #x_circ1 = random.randrange(10,50)
        #y_circ1 = random.randrange(10,50)
        #if abs(x_circ1 - x_circ)<10:
        #    continue
        #if abs(y_circ1 - y_min) < 10:
        #    continue
        out_square_count -= 1
        name = "trainglecirclerand" + str(out_square_count) + ".svg"

    dwg = svgwrite.Drawing(name, (svg_size_width, svg_size_height))

    #dwg.add(dwg.rect((x_min, y_min), (rec_size,rec_size),
    #    stroke=svgwrite.rgb(255, 0, 0, '%'), 
    #    fill='red')
    #)
    #dwg.add(dwg.circle(center=(x_circ,y_circ),
    #r=rad_circ, 
    #stroke=svgwrite.rgb(0, 0, 255, '%'),
    #fill='blue')
    #)
    #traingle_x_jitter = random.randrange(6,10)
    #traingle_y_jitter = random.randrange(8,12)
    x_ran =random.randrange(10,50)
    y_ran =random.randrange(10,50)
    draw_triangle((x_ran,y_ran), 10, 'white', rotate = 60)
    #draw_triangle((x_circ1,y_circ1), 10, 'rgb(0,255,0)', rotate = 60)
    dwg.save()
    drawing = svg2rlg(name)
    new_name = name.strip(".svg")
    new_name = new_name + ".png"
    renderPM.drawToFile(drawing, new_name, fmt="PNG")

print(count)
# Out:
# 68228

# %%
#CODE TO GET 1 POINTS circle 

svg_size_width = 70
svg_size_height = 70

in_square_count = 1000
out_square_count = 0
on_line_count = 0

count = 0


while (in_square_count != 0) or (on_line_count != 0) or (out_square_count != 0) :
    count += 1
    pos, x_min, y_min, x_max, y_max, x_circ, y_circ, rad_circ, rec_size = shape_create()
    if pos == 0:
        if in_square_count == 0:
            continue
        in_square_count -= 1
        name = "singlecircle" + str(in_square_count) + ".svg"
    if pos == 1:
        if on_line_count == 0:
            continue
        on_line_count -= 1
        name = "on_line" + str(on_line_count) + ".svg"
    if pos == 2:
        if out_square_count == 0:
            continue
        #x_circ1 = random.randrange(10,50)
        #y_circ1 = random.randrange(10,50)
        #if abs(x_circ1 - x_circ)<10:
        #    continue
        #if abs(y_circ1 - y_min) < 10:
        #    continue
        out_square_count -= 1
        name = "trainglecirclerand" + str(out_square_count) + ".svg"

    dwg = svgwrite.Drawing(name, (svg_size_width, svg_size_height))

    #dwg.add(dwg.rect((x_min, y_min), (rec_size,rec_size),
    #    stroke=svgwrite.rgb(255, 0, 0, '%'), 
    #    fill='red')
    #)
    dwg.add(dwg.circle(center=(x_circ,y_circ),
    r=rad_circ, 
    stroke=svgwrite.rgb(0, 0, 0, '%'),
    fill='white')
    )
    #traingle_x_jitter = random.randrange(6,10)
    #traingle_y_jitter = random.randrange(8,12)
    #x_ran =random.randrange(10,50)
    #y_ran =random.randrange(10,50)
    #draw_triangle((x_min+traingle_x_jitter,y_min-traingle_y_jitter), 10, 'rgb(0,255,0)', rotate = 60)
    #draw_triangle((x_circ1,y_circ1), 10, 'rgb(0,255,0)', rotate = 60)
    dwg.save()
    drawing = svg2rlg(name)
    new_name = name.strip(".svg")
    new_name = new_name + ".png"
    renderPM.drawToFile(drawing, new_name, fmt="PNG")

print(count)
# Out:
# 63416

# %%
#CODE TO GET 1 POINTS square 

svg_size_width = 70
svg_size_height = 70

in_square_count = 1000
out_square_count = 0
on_line_count = 0

count = 0


while (in_square_count != 0) or (on_line_count != 0) or (out_square_count != 0) :
    count += 1
    pos, x_min, y_min, x_max, y_max, x_circ, y_circ, rad_circ, rec_size = shape_create()
    if pos == 0:
        if in_square_count == 0:
            continue
        '''
        x_circ1 = random.randrange(10,50)
        y_circ1 = random.randrange(10,50)
        if x_circ1 < (x_max + rad_circ + 10) and x_circ1 > (x_min - rad_circ -10) :
            if y_circ1 < (y_max + rad_circ +10) and y_circ1 > (y_min - rad_circ -10) :
                if abs(x_min - x_circ1) <= rad_circ:
                    continue
                elif abs(x_max - x_circ1) <= rad_circ:
                    continue
                elif abs(y_min - y_circ1) <= rad_circ:
                    continue
                elif abs(y_max - y_circ1) <= rad_circ:
                    continue
                else :
                    continue
            else:
                in_square_count -= 1
                name = "traingleout" + str(in_square_count) + ".svg"
        else:
            in_square_count -= 1
            name = "traingleout" + str(in_square_count) + ".svg"
        '''
        in_square_count -= 1
        name = "singlesquare" + str(in_square_count) + ".svg"
    if pos == 1:
        if on_line_count == 0:
            continue
        on_line_count -= 1
        name = "on_line" + str(on_line_count) + ".svg"
    if pos == 2:
        if out_square_count == 0:
            continue
        #x_circ1 = random.randrange(10,50)
        #y_circ1 = random.randrange(10,50)
        #if abs(x_circ1 - x_circ)<10:
        #    continue
        #if abs(y_circ1 - y_min) < 10:
        #    continue
        out_square_count -= 1
        name = "trainglecirclerand" + str(out_square_count) + ".svg"

    dwg = svgwrite.Drawing(name, (svg_size_width, svg_size_height))

    dwg.add(dwg.rect((x_min, y_min), (rec_size,rec_size),
        stroke=svgwrite.rgb(0, 0, 0, '%'), 
        fill='white')
    )
    #dwg.add(dwg.circle(center=(x_circ,y_circ),
    #r=rad_circ, 
    #stroke=svgwrite.rgb(0, 0, 255, '%'),
    #fill='blue')
    #)
    #traingle_x_jitter = random.randrange(6,10)
    #traingle_y_jitter = random.randrange(8,12)
    #x_ran =random.randrange(10,50)
    #y_ran =random.randrange(10,50)
    #draw_triangle((x_min+traingle_x_jitter,y_min-traingle_y_jitter), 10, 'rgb(0,255,0)', rotate = 60)
    #draw_triangle((x_circ1,y_circ1), 10, 'rgb(0,255,0)', rotate = 60)
    dwg.save()
    drawing = svg2rlg(name)
    new_name = name.strip(".svg")
    new_name = new_name + ".png"
    renderPM.drawToFile(drawing, new_name, fmt="PNG")

print(count)
# Out:
# 70693

# %%
#CODE TO GET 5 point circle out

svg_size_width = 70
svg_size_height = 70

in_square_count = 0
out_square_count = 1500
on_line_count = 0

count = 0


while (in_square_count != 0) or (on_line_count != 0) or (out_square_count != 0) :
    count += 1
    pos, x_min, y_min, x_max, y_max, x_circ, y_circ, rad_circ, rec_size = shape_create()
    if pos == 0:
        if in_square_count == 0:
            continue
        '''
        x_circ1 = random.randrange(10,50)
        y_circ1 = random.randrange(10,50)
        if x_circ1 < (x_max + rad_circ + 10) and x_circ1 > (x_min - rad_circ -10) :
            if y_circ1 < (y_max + rad_circ +10) and y_circ1 > (y_min - rad_circ -10) :
                if abs(x_min - x_circ1) <= rad_circ:
                    continue
                elif abs(x_max - x_circ1) <= rad_circ:
                    continue
                elif abs(y_min - y_circ1) <= rad_circ:
                    continue
                elif abs(y_max - y_circ1) <= rad_circ:
                    continue
                else :
                    continue
            else:
                in_square_count -= 1
                name = "traingleout" + str(in_square_count) + ".svg"
        else:
            in_square_count -= 1
            name = "traingleout" + str(in_square_count) + ".svg"
        '''
        in_square_count -= 1
        name = "insquare4" + str(in_square_count) + ".svg"
    if pos == 1:
        if on_line_count == 0:
            continue
        on_line_count -= 1
        name = "on_line" + str(on_line_count) + ".svg"
    if pos == 2:
        if abs(y_circ-y_min)<10:
            continue
        if out_square_count == 0:
            continue
        #x_circ1 = random.randrange(10,50)
        #y_circ1 = random.randrange(10,50)
        #if abs(x_circ1 - x_circ)<10:
        #    continue
        #if abs(y_circ1 - y_min) < 10:
        #    continue
        out_square_count -= 1
        name = "outsquarecircle" + str(out_square_count) + ".svg"

    dwg = svgwrite.Drawing(name, (svg_size_width, svg_size_height))

    dwg.add(dwg.rect((x_min, y_min), (rec_size,rec_size),
        stroke=svgwrite.rgb(0, 0, 0, '%'), 
        fill='white')
    )
    dwg.add(dwg.circle(center=(x_circ,y_circ),
    r=rad_circ, 
    stroke=svgwrite.rgb(0, 0, 0, '%'),
    fill='white')
    )
    traingle_x_jitter = random.randrange(6,10)
    traingle_y_jitter = random.randrange(8,12)
    #x_ran =random.randrange(10,50)
    #y_ran =random.randrange(10,50)
    draw_triangle((x_min+traingle_x_jitter,y_min-traingle_y_jitter), 10, 'white', rotate = 60)
    #draw_triangle((x_circ1,y_circ1), 10, 'rgb(0,255,0)', rotate = 60)
    dwg.save()
    drawing = svg2rlg(name)
    new_name = name.strip(".svg")
    new_name = new_name + ".png"
    renderPM.drawToFile(drawing, new_name, fmt="PNG")

print(count)
# Out:
# 2913

# %%
#CODE TO GET 5 point triangle out

svg_size_width = 70
svg_size_height = 70

in_square_count = 1500
out_square_count = 0
on_line_count = 0

count = 0


while (in_square_count != 0) or (on_line_count != 0) or (out_square_count != 0) :
    count += 1
    pos, x_min, y_min, x_max, y_max, x_circ, y_circ, rad_circ, rec_size = shape_create()
    if pos == 0:
        if in_square_count == 0:
            continue
    
        x_circ1 = random.randrange(10,50)
        y_circ1 = random.randrange(10,50)
        if x_circ1 < (x_max + rad_circ + 10) and x_circ1 > (x_min - rad_circ -10) :
            if y_circ1 < (y_max + rad_circ +10) and y_circ1 > (y_min - rad_circ -10) :
                if abs(x_min - x_circ1) <= rad_circ:
                    continue
                elif abs(x_max - x_circ1) <= rad_circ:
                    continue
                elif abs(y_min - y_circ1) <= rad_circ:
                    continue
                elif abs(y_max - y_circ1) <= rad_circ:
                    continue
                else :
                    continue
            else:
                in_square_count -= 1
                name = "traingleout" + str(in_square_count) + ".svg"
        else:
            in_square_count -= 1
            name = "traingleout" + str(in_square_count) + ".svg"
    if pos == 1:
        if on_line_count == 0:
            continue
        on_line_count -= 1
        name = "on_line" + str(on_line_count) + ".svg"
    if pos == 2:
        if out_square_count == 0:
            continue
        #x_circ1 = random.randrange(10,50)
        #y_circ1 = random.randrange(10,50)
        #if abs(x_circ1 - x_circ)<10:
        #    continue
        #if abs(y_circ1 - y_min) < 10:
        #    continue
        out_square_count -= 1
        name = "outsquaretriangle" + str(out_square_count) + ".svg"

    dwg = svgwrite.Drawing(name, (svg_size_width, svg_size_height))

    dwg.add(dwg.rect((x_min, y_min), (rec_size,rec_size),
        stroke=svgwrite.rgb(0, 0, 0, '%'), 
        fill='white')
    )
    dwg.add(dwg.circle(center=(x_circ,y_circ),
    r=rad_circ, 
    stroke=svgwrite.rgb(0, 0, 0, '%'),
    fill='white')
    )
    traingle_x_jitter = random.randrange(6,10)
    traingle_y_jitter = random.randrange(8,12)
    #x_ran =random.randrange(10,50)
    #y_ran =random.randrange(10,50)
    #draw_triangle((x_min+traingle_x_jitter,y_min-traingle_y_jitter), 10, 'rgb(0,255,0)', rotate = 60)
    draw_triangle((x_circ1,y_circ1), 10, 'white', rotate = 60)
    dwg.save()
    drawing = svg2rlg(name)
    new_name = name.strip(".svg")
    new_name = new_name + ".png"
    renderPM.drawToFile(drawing, new_name, fmt="PNG")

print(count)
# Out:
# 287060

# %%
#CODE TO GET 3 point all random

svg_size_width = 70
svg_size_height = 70

in_square_count = 0
out_square_count = 3000
on_line_count = 0

count = 0


while (in_square_count != 0) or (on_line_count != 0) or (out_square_count != 0) :
    count += 1
    pos, x_min, y_min, x_max, y_max, x_circ, y_circ, rad_circ, rec_size = shape_create()
    if pos == 0:
        if in_square_count == 0:
            continue
        '''
        x_circ1 = random.randrange(10,50)
        y_circ1 = random.randrange(10,50)
        if x_circ1 < (x_max + rad_circ + 10) and x_circ1 > (x_min - rad_circ -10) :
            if y_circ1 < (y_max + rad_circ +10) and y_circ1 > (y_min - rad_circ -10) :
                if abs(x_min - x_circ1) <= rad_circ:
                    continue
                elif abs(x_max - x_circ1) <= rad_circ:
                    continue
                elif abs(y_min - y_circ1) <= rad_circ:
                    continue
                elif abs(y_max - y_circ1) <= rad_circ:
                    continue
                else :
                    continue
            else:
                in_square_count -= 1
                name = "traingleout" + str(in_square_count) + ".svg"
        else:
            in_square_count -= 1
            name = "traingleout" + str(in_square_count) + ".svg"
        '''
        in_square_count -= 1
        name = "insquare4" + str(in_square_count) + ".svg"
    if pos == 1:
        if on_line_count == 0:
            continue
        on_line_count -= 1
        name = "on_line" + str(on_line_count) + ".svg"
    if pos == 2:
        if out_square_count == 0:
            continue
        x_circ1 = random.randrange(10,50)
        y_circ1 = random.randrange(10,50)
        if abs(x_circ1 - x_circ)<10:
            continue
        if abs(y_circ1 - y_circ) < 10:
            continue
        out_square_count -= 1
        name = "rand3" + str(out_square_count) + ".svg"

    dwg = svgwrite.Drawing(name, (svg_size_width, svg_size_height))

    dwg.add(dwg.rect((x_min, y_min), (rec_size,rec_size),
        stroke=svgwrite.rgb(0, 0, 0, '%'), 
        fill='white')
    )
    dwg.add(dwg.circle(center=(x_circ,y_circ),
    r=rad_circ, 
    stroke=svgwrite.rgb(0, 0, 0, '%'),
    fill='white')
    )
    traingle_x_jitter = random.randrange(6,10)
    traingle_y_jitter = random.randrange(8,12)
    #x_ran =random.randrange(10,50)
    #y_ran =random.randrange(10,50)
    #draw_triangle((x_min+traingle_x_jitter,y_min-traingle_y_jitter), 10, 'rgb(0,255,0)', rotate = 60)
    draw_triangle((x_circ1,y_circ1), 10, 'white', rotate = 60)
    dwg.save()
    drawing = svg2rlg(name)
    new_name = name.strip(".svg")
    new_name = new_name + ".png"
    renderPM.drawToFile(drawing, new_name, fmt="PNG")

print(count)
# Out:
# 10916

# %%
#CODE TO 2 outsquare

svg_size_width = 70
svg_size_height = 70

in_square_count = 0
out_square_count = 1000
on_line_count = 0

count = 0


while (in_square_count != 0) or (on_line_count != 0) or (out_square_count != 0) :
    count += 1
    pos, x_min, y_min, x_max, y_max, x_circ, y_circ, rad_circ, rec_size = shape_create()
    if pos == 0:
        if in_square_count == 0:
            continue
        '''
        x_circ1 = random.randrange(10,50)
        y_circ1 = random.randrange(10,50)
        if x_circ1 < (x_max + rad_circ + 10) and x_circ1 > (x_min - rad_circ -10) :
            if y_circ1 < (y_max + rad_circ +10) and y_circ1 > (y_min - rad_circ -10) :
                if abs(x_min - x_circ1) <= rad_circ:
                    continue
                elif abs(x_max - x_circ1) <= rad_circ:
                    continue
                elif abs(y_min - y_circ1) <= rad_circ:
                    continue
                elif abs(y_max - y_circ1) <= rad_circ:
                    continue
                else :
                    continue
            else:
                in_square_count -= 1
                name = "traingleout" + str(in_square_count) + ".svg"
        else:
            in_square_count -= 1
            name = "traingleout" + str(in_square_count) + ".svg"
        '''
        in_square_count -= 1
        name = "insquare4" + str(in_square_count) + ".svg"
    if pos == 1:
        if on_line_count == 0:
            continue
        on_line_count -= 1
        name = "on_line" + str(on_line_count) + ".svg"
    if pos == 2:
        if out_square_count == 0:
            continue
        #x_circ1 = random.randrange(10,50)
        #y_circ1 = random.randrange(10,50)
        #if abs(x_circ1 - x_circ)<10:
        #    continue
        #if abs(y_circ1 - y_min) < 10:
        #    continue
        out_square_count -= 1
        name = "outsquare" + str(out_square_count) + ".svg"

    dwg = svgwrite.Drawing(name, (svg_size_width, svg_size_height))

    dwg.add(dwg.rect((x_min, y_min), (rec_size,rec_size),
        stroke=svgwrite.rgb(0, 0, 0, '%'), 
        fill='white')
    )
    dwg.add(dwg.circle(center=(x_circ,y_circ),
    r=rad_circ, 
    stroke=svgwrite.rgb(0, 0, 0, '%'),
    fill='white')
    )
    traingle_x_jitter = random.randrange(6,10)
    traingle_y_jitter = random.randrange(8,12)
    #x_ran =random.randrange(10,50)
    #y_ran =random.randrange(10,50)
    #draw_triangle((x_min+traingle_x_jitter,y_min-traingle_y_jitter), 10, 'rgb(0,255,0)', rotate = 60)
    #draw_triangle((x_circ1,y_circ1), 10, 'rgb(0,255,0)', rotate = 60)
    dwg.save()
    drawing = svg2rlg(name)
    new_name = name.strip(".svg")
    new_name = new_name + ".png"
    renderPM.drawToFile(drawing, new_name, fmt="PNG")

print(count)
# Out:
# 1239

# %%
#CODE TO 2 traingle outsquare

svg_size_width = 70
svg_size_height = 70

in_square_count = 0
out_square_count = 1000
on_line_count = 0

count = 0


while (in_square_count != 0) or (on_line_count != 0) or (out_square_count != 0) :
    count += 1
    pos, x_min, y_min, x_max, y_max, x_circ, y_circ, rad_circ, rec_size = shape_create()
    if pos == 0:
        if in_square_count == 0:
            continue
        '''
        x_circ1 = random.randrange(10,50)
        y_circ1 = random.randrange(10,50)
        if x_circ1 < (x_max + rad_circ + 10) and x_circ1 > (x_min - rad_circ -10) :
            if y_circ1 < (y_max + rad_circ +10) and y_circ1 > (y_min - rad_circ -10) :
                if abs(x_min - x_circ1) <= rad_circ:
                    continue
                elif abs(x_max - x_circ1) <= rad_circ:
                    continue
                elif abs(y_min - y_circ1) <= rad_circ:
                    continue
                elif abs(y_max - y_circ1) <= rad_circ:
                    continue
                else :
                    continue
            else:
                in_square_count -= 1
                name = "traingleout" + str(in_square_count) + ".svg"
        else:
            in_square_count -= 1
            name = "traingleout" + str(in_square_count) + ".svg"
        '''
        in_square_count -= 1
        name = "trianglerandsquare" + str(in_square_count) + ".svg"
    if pos == 1:
        if on_line_count == 0:
            continue
        on_line_count -= 1
        name = "on_line" + str(on_line_count) + ".svg"
    if pos == 2:
        if out_square_count == 0:
            continue
        #x_circ1 = random.randrange(10,50)
        #y_circ1 = random.randrange(10,50)
        #if abs(x_circ1 - x_circ)<10:
        #    continue
        #if abs(y_circ1 - y_min) < 10:
        #    continue
        x_ran =random.randrange(10,50)
        y_ran =random.randrange(10,50)
        if abs(y_ran - y_min) < 15:
            continue

        out_square_count -= 1
        name = "traigeoutsquare" + str(out_square_count) + ".svg"

    dwg = svgwrite.Drawing(name, (svg_size_width, svg_size_height))
    x_ran =random.randrange(10,50)
    y_ran =random.randrange(10,50)

    dwg.add(dwg.rect((x_min, y_min), (rec_size,rec_size),
        stroke=svgwrite.rgb(0, 0, 0, '%'), 
        fill='white')
    )
    #dwg.add(dwg.circle(center=(x_circ,y_circ),
    #r=rad_circ, 
    #stroke=svgwrite.rgb(0, 0, 255, '%'),
    #fill='blue')
    #)
    traingle_x_jitter = random.randrange(6,10)
    traingle_y_jitter = random.randrange(8,12)
    
    #draw_triangle((x_min+traingle_x_jitter,y_min-traingle_y_jitter), 10, 'rgb(0,255,0)', rotate = 60)
    draw_triangle((x_ran,y_ran), 10, 'white', rotate = 60)
    
    dwg.save()
    drawing = svg2rlg(name)
    new_name = name.strip(".svg")
    new_name = new_name + ".png"
    renderPM.drawToFile(drawing, new_name, fmt="PNG")

print(count)
# Out:
# 2985

# %%
#CODE TO 2 traingle circle

svg_size_width = 70
svg_size_height = 70

in_square_count = 0
out_square_count = 1000
on_line_count = 0

count = 0


while (in_square_count != 0) or (on_line_count != 0) or (out_square_count != 0) :
    count += 1
    pos, x_min, y_min, x_max, y_max, x_circ, y_circ, rad_circ, rec_size = shape_create()
    if pos == 0:
        if in_square_count == 0:
            continue
        '''
        x_circ1 = random.randrange(10,50)
        y_circ1 = random.randrange(10,50)
        if x_circ1 < (x_max + rad_circ + 10) and x_circ1 > (x_min - rad_circ -10) :
            if y_circ1 < (y_max + rad_circ +10) and y_circ1 > (y_min - rad_circ -10) :
                if abs(x_min - x_circ1) <= rad_circ:
                    continue
                elif abs(x_max - x_circ1) <= rad_circ:
                    continue
                elif abs(y_min - y_circ1) <= rad_circ:
                    continue
                elif abs(y_max - y_circ1) <= rad_circ:
                    continue
                else :
                    continue
            else:
                in_square_count -= 1
                name = "traingleout" + str(in_square_count) + ".svg"
        else:
            in_square_count -= 1
            name = "traingleout" + str(in_square_count) + ".svg"
        '''
        in_square_count -= 1
        name = "trianglerandsquare" + str(in_square_count) + ".svg"
    if pos == 1:
        if on_line_count == 0:
            continue
        on_line_count -= 1
        name = "on_line" + str(on_line_count) + ".svg"
    if pos == 2:
        if out_square_count == 0:
            continue
        #x_circ1 = random.randrange(10,50)
        #y_circ1 = random.randrange(10,50)
        if abs(x_circ1 - x_circ)<10:
            continue
        if abs(y_circ1 - y_circ) < 10:
            continue
        out_square_count -= 1
        name = "trainglecircle" + str(out_square_count) + ".svg"

    dwg = svgwrite.Drawing(name, (svg_size_width, svg_size_height))
    x_ran =random.randrange(10,50)
    y_ran =random.randrange(10,50)
    
        

    #dwg.add(dwg.rect((x_min, y_min), (rec_size,rec_size),
    #    stroke=svgwrite.rgb(255, 0, 0, '%'), 
    #    fill='red')
    #)
    dwg.add(dwg.circle(center=(x_circ,y_circ),
    r=rad_circ, 
    stroke=svgwrite.rgb(0, 0, 0, '%'),
    fill='white')
    )
    traingle_x_jitter = random.randrange(6,10)
    traingle_y_jitter = random.randrange(8,12)
    
    #draw_triangle((x_min+traingle_x_jitter,y_min-traingle_y_jitter), 10, 'rgb(0,255,0)', rotate = 60)
    draw_triangle((x_ran,y_ran), 10, 'white', rotate = 60)
    
    dwg.save()
    drawing = svg2rlg(name)
    new_name = name.strip(".svg")
    new_name = new_name + ".png"
    renderPM.drawToFile(drawing, new_name, fmt="PNG")

print(count)
# Out:
# 3363
